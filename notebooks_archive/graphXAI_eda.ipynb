# %%
import graphxai
from graphxai.datasets import MUTAG

# %%
mutag = MUTAG('raw/mutag')
# Out:
# ...
# Processing...
# Done!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mutag = MUTAG('raw/mutag')
#
# File c:\working\graphxai\graphxai\datasets\real_world\MUTAG.py:48, in MUTAG.__init__(self, root, use_fixed_split, generate, split_sizes, seed)
#      45 self.graphs = TUDataset(root=root, name='MUTAG')
#      46 # self.graphs retains all qualitative and quantitative attributes from PyG
# ---> 48 self.__make_explanations()
#      50 super().__init__(name = 'MUTAG', seed = seed, split_sizes = split_sizes)
#
# File c:\working\graphxai\graphxai\datasets\real_world\MUTAG.py:73, in MUTAG.__make_explanations(self)
#      69 # Screen for NH2:
#      70 for n in molG.nodes():
#      71     # Screen all nodes through match_NH2
#      72     # match_NH2 is very quick
# ---> 73     m = match_NH2(molG, n)
#      74     if m:
# ...
