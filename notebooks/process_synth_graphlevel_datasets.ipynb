# %%
import torch
import torch_geometric
import pickle

# %%
ds = torch_geometric.datasets.TUDataset(root="../raw/TUDataset", name="MUTAG")
# Out:
# ...
# Processing...
# Done!

# %%
for something in ds:
    print(something)
    break
# Out:
# Data(edge_index=[2, 38], x=[17, 7], edge_attr=[38, 4], y=[1])
